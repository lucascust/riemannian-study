# %%
# Authors: Alexandre Barachant <alexandre.barachant@gmail.com>
#
# License: BSD (3-clause)
import numpy as np

from pyriemann.estimation import XdawnCovariances
from pyriemann.tangentspace import TangentSpace
from pyriemann.utils.viz import plot_confusion_matrix

import mne
from mne import io
from mne.datasets import sample

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression

from matplotlib import pyplot as plt
print(__doc__)
data_path = sample.data_path()
# Out:
# Automatically created module for IPython interactive environment

# %%
# Modificação: Mudança de database utilizada (Atual = exoesqueleto barachant)

#raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
raw_fname = '../data/record-[2014.03.10-20.26.46]_raw.fif'
#event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
event_fname = '../data/record-[2014.03.10-20.41.35]-eve.fif'

tmin, tmax = -0., 1
# Modificação: Atualização de labels para frequencias
#event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)
event_id = {'steady': 1, '13hz': 2, '17hz': 3, '21hz': 4}

# %%
# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir') # replace baselining with high-pass
events = mne.read_events(event_fname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4c11feeb7ffc> in <module>
#       1 # Setup for reading the raw data
# ----> 2 raw = io.Raw(raw_fname, preload=True, verbose=False)
#       3 raw.filter(2, None, method='iir') # replace baselining with high-pass
#       4 events = mne.read_events(event_fname)
#
# <decorator-gen-169> in __init__(self, fname, allow_maxshield, preload, verbose)
#
# ~\anaconda3\lib\site-packages\mne\io\fiff\raw.py in __init__(self, fname, allow_maxshield, preload, verbose)
#      77         while next_fname is not None:
#      78             raw, next_fname, buffer_size_sec = \
# ---> 79                 self._read_raw_file(next_fname, allow_maxshield,
#      80                                     preload, do_check_fname)
#      81             do_check_fname = False
#
# <decorator-gen-170> in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#
# ~\anaconda3\lib\site-packages\mne\io\fiff\raw.py in _read_raw_file(self, fname, allow_maxshield, preload, do_check_fname, verbose)
#     145             whole_file = True
#     146         fname_rep = _get_fname_rep(fname)
# --> 147         ff, tree, _ = fiff_open(fname, preload=whole_file)
#     148         with ff as fid:
#     149             #   Read the measurement info
#
# <decorator-gen-6> in fiff_open(fname, preload, verbose)
#
# ~\anaconda3\lib\site-packages\mne\io\open.py in fiff_open(fname, preload, verbose)
#     130     #   Check that this looks like a fif file
#     131     if tag.kind != FIFF.FIFF_FILE_ID:
# --> 132         raise ValueError('file does not start with a file id tag')
#     133
#     134     if tag.type != FIFF.FIFFT_ID_STRUCT:
#
# ValueError: file does not start with a file id tag

# %%
# Modificação: Retirada de channel MEG, por não tê-lo na novadatabase utilizada
#raw.info['bads'] = ['MEG 2443'] # set bad channels
#picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False, exclude='bads')

picks = mne.pick_types(raw.info, eeg=True, stim=False, eog=False)

# %%
# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False, picks=picks, baseline=None, preload=True, verbose=False)

# %%
labels = epochs.events[:, -1]
evoked = epochs.average()

# %%
## Decoding in tangent space with a logistic regression

n_components = 2 # pick some components

# Define a monte-carlo cross-validation generator (reduce variance):
cv = KFold(n_splits=10, shuffle=True, random_state=42)
epochs_data = epochs.get_data()

clf = make_pipeline(XdawnCovariances(n_components), TangentSpace(metric='riemann'), LogisticRegression())

preds = np.zeros(len(labels))

for train_idx, test_idx in cv.split(epochs_data):
    y_train, y_test = labels[train_idx], labels[test_idx]
    
    clf.fit(epochs_data[train_idx], y_train)
    preds[test_idx] = clf.predict(epochs_data[test_idx])

# Printing the results
acc = np.mean(preds == labels)
print("Classification accuracy: %f " % (acc))

# Modificação: Alteração das labels
#names = ['audio left', 'audio right', 'vis left', 'vis right']
names = ['steady', '13hz', '21hz', '17hz']


plot_confusion_matrix(preds, labels, names)
plt.show()
# Out:
# Classification accuracy: 0.218750
